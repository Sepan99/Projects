# %%
import pandas as pd

# %%
#Importing and reading the csv file
food = pd.read_csv("C:/Users/SterSc/Downloads/food_coded.csv")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 20)

# %%
#Creating a new column for grading
food["Letter_grading"] = food["GPA"]

food["Letter_grading"] = pd.to_numeric(food["Letter_grading"], errors="coerce")

food["Letter_grading"] = food["Letter_grading"].fillna(food["Letter_grading"])

# %%
#Using a function to fill the new column with letter grading
def map_to_letter_grade(score):
    if isinstance(score, str):
        return score
    elif score >= 3.8:
        return "A+"
    elif score >= 3.5:
        return "A"
    elif score >= 3.0:
        return "B+"
    elif score >= 2.7:
        return "B"
    elif score >= 1.7:
        return "C"
    elif score >= 1.0:
        return "D"
    elif score >= 0.0:
        return "F"
    else:
        return None
    
food["Letter_grading"] = food["Letter_grading"].apply(map_to_letter_grade)

# %%
#Moving the new column
letter_grade = food.pop("Letter_grading")

food.insert(1, "Letter_grading", letter_grade)

# %%
#Based on the dataset source info, replacing every confusing 1, 2 data
food["Gender"].replace({1: "Female", 2: "Male"}, inplace=True)
food["breakfast"].replace({1: "Cereal option", 2: "Donut option"}, inplace=True)
food["coffee"].replace({1: "Creamy frapucciono", 2: "Espresso"}, inplace=True)
food["drink"].replace({1: "Orange juice", 2: "Soda"}, inplace=True)
food["fries"].replace({1: "Mcdonald’s fries", 2: "home fries"}, inplace=True)
food["soup"].replace({1: "veggie soup", 2: "creamy soup"}, inplace=True)
food["sports"].replace({1: "Yes", 2: "No", 99: "no answer"}, inplace=True)
food["vitamins"].replace({1: "Yes", 2: "No"}, inplace=True)

# %%
#Based on the dataset source info, replacing every other confusing data
food["calories_day"].replace({1: "i dont know how many calories i should consume",
                              2: "it is not at all important",
                              3: "it is moderately important",
                              4: "it is very important"
                             }, inplace=True)


food["comfort_food_reasons_coded.1"].replace({1: "stress",
                                            2: "boredom",
                                            3: "depression/sadness",
                                            4: "hunger",
                                            5: "laziness",
                                            6: "cold weather",
                                            7: "happiness",
                                            8: "watching TV",
                                            9: None
                                             }, inplace=True)


food["cook"].replace({1: "Every day",
                      2: "A couple of times a week",
                      3: "not very often",
                      4: "during holidays",
                      5: "Never",
                      }, inplace=True)


food["cuisine"].replace({1: "american",
                         2: "mexican/Spanish",
                         3: "korean/Asian",
                         4: "indian",
                         5: "american inspired international dishes",
                         6: "other"
                         }, inplace=True)


food["diet_current_coded"].replace({1: "balanced",
                                    2: "random",
                                    3: "the same thing everyday",
                                    4: "unclear"
                                    }, inplace=True)


food["eating_changes_coded1"].replace({1: "eat faster",
                                       2: "bigger quantity",
                                       3: "worse quality",
                                       4: "same food",
                                       5: "healthier",
                                       6: "unclear",
                                       7: "more coffee",
                                       8: "less food",
                                       9: "more sweets",
                                       10: "timing",
                                       11: "more snacking",
                                       12: "more water",
                                       13: "more variety"
                                       }, inplace=True)


food["eating_out"].replace({1: "never",
                            2: "1-2 times",
                            3: "2-3 times",
                            4: "3-5 times",
                            5: "everyday",
                             }, inplace=True)


food["employment"].replace({1: "never",
                            2: "yes full time",
                            3: "yes part time",
                            4: "no",
                            5: "other",
                            }, inplace=True)


food["exercise"].replace({1: "everyday",
                          2: "2-3 times",
                          3: "once a week",
                          4: "sometimes",
                          5: "never",
                           }, inplace=True)


food["ethnic_food"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)


food["father_education"].replace({1: "less than high school",
                                  2: "high school degree",
                                  3: "some college degree",
                                  4: "college degree",
                                  5: "graduate degree",
                                   }, inplace=True)


food["fav_food"].replace({1: "cooked at home",
                          2: "store bought",
                          3: "both",
                           }, inplace=True)


food["fruit_day"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)


food["grade_level"].replace({1: "freshman",
                             2: "sophomore",
                             3: "junior",
                             4: "senior",
                              }, inplace=True)


food["greek_food"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)


food["ideal_diet_coded"].replace({1: "portion control",
                                  2: "eating healthier",
                                  3: "balance",
                                  4: "less sugar",
                                  5: "home cooked",
                                  6: "current diet",
                                  7: "more protein",
                                  8: "unclear",
                                   }, inplace=True)


food["income"].replace({1: "less than $15,000",
                        2: "$15,001 to $30,000",
                        3: "$30,001 to $50,000",
                        4: "$50,001 to $70,000",
                        5: "$70,001 to $100,000",
                        6: "more than $100,000",
                         }, inplace=True)


food["indian_food"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)


food["italian_food"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)


food["marital_status"].replace({1: "single",
                                2: "in relationship ",
                                3: "cohabiting",
                                4: "married",
                                5: "divorced",
                                6: "widowed",
                                 }, inplace=True)


food["mother_education"].replace({1: "less than high school",
                                  2: "high school degree",
                                  3: "some college degree",
                                  4: "college degree",
                                  5: "graduate degree",
                                   }, inplace=True)


food["nutritional_check"].replace({1: "never",
                                   2: "certain products only",
                                   3: "very rarely",
                                   4: "most products",
                                   5: "everything",
                                    }, inplace=True)


food["on_off_campus"].replace({1: "on campus",
                               2: "out of campus",
                               3: "with parents",
                               4: "own house",
                                }, inplace=True)


food["parents_cook"].replace({1: "Every day",
                      2: "A couple of times a week",
                      3: "not very often",
                      4: "during holidays",
                      5: "Never",
                      }, inplace=True)


food["pay_meal_out"].replace({1: "less than $5.00",
                              2: "$5.01 to $10.00",
                              3: "$10.01 to $20.00",
                              4: "$20.01 to $30.00",
                              5: "$30.01 to $40.00",
                              6: "more than $40.01",
                               }, inplace=True)


food["persian_food"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)


food["self_perception_weight"].replace({1: "slim",
                                        2: "very fit",
                                        3: "just right",
                                        4: "slightly overweight",
                                        5: "overweight",
                                        6: "unknown",
                                         }, inplace=True)


food["thai_food"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)


food["veggies_day"].replace({1: "very unlikely",
                            2: "unlikely",
                            3: "neutral",
                            4: "likely",
                            5: "verylikely",
                            }, inplace=True)

# %%
#Changing the scores from (1 is the hieghest) to (10 is the heighest)
food["healthy_feeling"] = [11 - x for x in food["healthy_feeling"]]
food["life_rewarding"] = [11 - x for x in food["life_rewarding"]]

# %%
#Renaming some columns
food = food.rename(columns = {"calories_chicken": "calories_in_chicken_piadina",
                              "calories_day": "calories_consumption_per_day_importance",
                              "calories_scone": "calories_in_scone_starbucks",
                              "comfort_food_reasons_coded": "food_reasons_simple",
                              "comfort_food_reasons_coded.1": "comfort_food_reason_simple",
                              "cook": "cooking_time",
                              "cuisine": "cuisine_growing_up",
                              "diet_current_coded": "diet_current_simple",
                              "eating_changes": "eating_changes_collage_entrance",
                              "eating_changes_coded1": "eating_changes_collage_entrance_simple",
                              "eating_out": "eating_out_per_week",
                              "ethnic_food": "ethnic_food_per_week",
                              "greek_food": "greek_food_per_week",
                              "exercise": "exercises_per_week",
                              "fav_food": "home_store_food",
                              "fav_cuisine_coded": "fav_cuisine_simple",
                              "healthy_feeling": "healthy_feeling_of_10",
                              "greek_food": "greek_food_per_week",
                              "indian_food": "indian_food_per_week",
                              "italian_food": "italian_food_per_week",
                              "thai_food": "thai_food_per_week",
                              "ideal_diet_coded": "ideal_diet_simple",
                              "life_rewarding": "life_rewarding_of_10",
                              "on_off_campus": "on_off_campus_living",
                              "parents_cook": "parents_cook_per_week",
                              "persian_food": "persian_food_per_week",
                             }
                  )

# %%
#Removing unnecessary columns
food = food.drop(["food_reasons_simple", "eating_changes_coded", "fav_cuisine_simple"], axis=1)

# %%
#reordering columns
food.columns
# Out:
# Index(['GPA', 'Letter_grading', 'Gender', 'breakfast',
#        'calories_in_chicken_piadina',
#        'calories_consumption_per_day_importance',
#        'calories_in_scone_starbucks', 'coffee', 'comfort_food',
#        'comfort_food_reasons', 'cooking_time', 'comfort_food_reason_simple',
#        'cuisine_growing_up', 'diet_current', 'diet_current_simple', 'drink',
#        'eating_changes_collage_entrance',
#        'eating_changes_collage_entrance_simple', 'eating_out_per_week',
#        'employment', 'ethnic_food_per_week', 'exercises_per_week',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'home_store_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food_per_week', 'healthy_feeling_of_10',
#        'healthy_meal', 'ideal_diet', 'ideal_diet_simple', 'income',
#        'indian_food_per_week', 'italian_food_per_week', 'life_rewarding_of_10',
#        'marital_status', 'meals_dinner_friend', 'mother_education',
# ...

# %%
new_order = ['GPA', 'Letter_grading', 'Gender', 'marital_status', 'weight', 'breakfast', 'drink', 'coffee', 'soup', 
             'fries', 'diet_current', 'diet_current_simple', 'vitamins', 'veggies_day', 'fruit_day', 
             'eating_changes_collage_entrance','eating_changes_collage_entrance_simple', 'healthy_meal', 
             'ideal_diet', 'ideal_diet_simple', 'healthy_feeling_of_10', 'food_childhood',
             'comfort_food', 'comfort_food_reasons', 'comfort_food_reason_simple', 'cuisine_growing_up',
             'ethnic_food_per_week', 'greek_food_per_week', 'indian_food_per_week', 'italian_food_per_week',
             'persian_food_per_week', 'thai_food_per_week', 'fav_cuisine', 'parents_cook_per_week',  
             'eating_out_per_week', 'cooking_time', 'home_store_food', 'pay_meal_out', 'employment', 'income',
             'eating_changes_collage_entrance', 'eating_changes_collage_entrance_simple', 'meals_dinner_friend',
             'grade_level', 'on_off_campus_living', 'father_education','father_profession', 'mother_education',
             'mother_profession', 'sports', 'type_sports', 'exercises_per_week', 'calories_in_chicken_piadina', 
             'calories_consumption_per_day_importance', 'calories_in_scone_starbucks', 'tortilla_calories',
             'turkey_calories', 'waffle_calories', 'life_rewarding_of_10']

# %%
food = food.reindex(columns=new_order)

# %%
#Saving the into a new csv
food.to_csv("food chain data", index=False)
